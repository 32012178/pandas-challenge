# %%
import pandas as pd

# %%
# File to load (remember these changes)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read school and student data file and store into Panda dataframes 
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

#Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

df = school_data_complete

# %%
school_data_complete.head()
# Out:
#    Student ID     student_name gender  year        school_name  reading_score  \
# 0           0     Paul Bradley      M     9  Huang High School             96
# 1           1     Victor Smith      M    12  Huang High School             90
# 2           2  Kevin Rodriguez      M    12  Huang High School             41
# 3           3    Richard Scott      M    12  Huang High School             89
# 4           4       Bonnie Ray      F     9  Huang High School             87
#
#    maths_score  School ID        type  size   budget
# 0           94          0  Government  2917  1910635
# 1           43          0  Government  2917  1910635
# 2           76          0  Government  2917  1910635
# 3           86          0  Government  2917  1910635
# 4           69          0  Government  2917  1910635

# %%
df.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'year', 'school_name',
#        'reading_score', 'maths_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
# collect a list of all the unique values in school
total_school = len(school_data_complete["School ID"].unique())
print(total_school)
# Out:
# 15

# %%
# collect a list of total students
total_students = len(school_data_complete["student_name"].nunique())
print(total_students)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14596\2514577688.py in <module>
#       1 # collect a list of total students
# ----> 2 total_students = len(school_data_complete["student_name"].nunique())
#       3 print(total_students)
#
# TypeError: object of type 'int' has no len()

# %%
# total budget 
total_budget = int(school_data_complete["budget"].sum()) 
print(total_budget)
# Out:
# 82932329558

# %%
averageMathScore = school_data_complete["maths_score"].mean()
averageReadingScore = school_data_complete["reading_score"].mean()
print(averageMathScore)
print(averageReadingScore)
# Out:
# 70.33819249425581
# 69.98013786060761

# %%
# percent passing math
passing_math = (school_data_complete["maths_score"]  > 50).mean()
print(passing_math)
# Out:
# 0.844319632371713

# %%
# percent passing english
passing_english = (school_data_complete["reading_score"] > 50).mean()
print(passing_english)
# Out:
# 0.82644881286699

# %%
# Save Local Government area summary
#total_schools = school_data_complete["School ID"].count()
#total_students = school_data_complete["Student ID"].sum()
#total_budget = school_data_complete["budget"].sum()
#averageMathScore = school_data_complete["maths_score"].mean()
##averageReadingScore = school_data_complete["reading_score"].mean()

# %%
data = [[total_school, total_students, total_budget, averageMathScore, averageReadingScore, passing_math, passing_english]]

# %%
df_government = pd.DataFrame(data, columns=['Total Schools', 'Total Students', 'Total Budget', 'Average Maths Score', 'Average Reading'])
df_government.head()
# Out:
#    Total Schools  Total Students  Total Budget  Average Maths Score  \
# 0             15           39170   82932329558            70.338192
#
#    Average Reading
# 0        69.980138

# %%
df_government[]

# %%
# Create a new Dataframe using count and total, and mean
#local_government_df = df.loc[:, ["School ID", "student_name", "budget", "maths_score", "reading_score"]]
#local_government_df
# Out:
#        School ID     student_name   budget  maths_score  reading_score
# 0              0     Paul Bradley  1910635           94             96
# 1              0     Victor Smith  1910635           43             90
# 2              0  Kevin Rodriguez  1910635           76             41
# 3              0    Richard Scott  1910635           86             89
# 4              0       Bonnie Ray  1910635           69             87
# ...          ...              ...      ...          ...            ...
# 39165         14     Donna Howard  1043130           48             51
# 39166         14        Dawn Bell  1043130           89             81
# 39167         14   Rebecca Tanner  1043130           99             99
# 39168         14     Desiree Kidd  1043130           77             72
# 39169         14  Carolyn Jackson  1043130           62             47
#
# [39170 rows x 5 columns]

# %%
#items_df = pd.DataFrame(raw_data_items, columns=[
                        "customer_id", "item", "cost"])
#summary_df

# %%
# create an overview table (Q2)

# %%
# list the school names below
school_names = school_data_complete["school_name"].value_counts()
school_names.head()
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Name: school_name, dtype: int64

# %%
grouped_df = school_data_complete.groupby(["school_name", "type"])


grouped_df.count().head()
# Out:
#                                   Student ID  student_name  gender  year  \
# school_name          type
# Bailey High School   Government         4976          4976    4976  4976
# Cabrera High School  Independent        1858          1858    1858  1858
# Figueroa High School Government         2949          2949    2949  2949
# Ford High School     Government         2739          2739    2739  2739
# Griffin High School  Independent        1468          1468    1468  1468
#
#                                   reading_score  maths_score  School ID  size  \
# school_name          type
# Bailey High School   Government            4976         4976       4976  4976
# Cabrera High School  Independent           1858         1858       1858  1858
# Figueroa High School Government            2949         2949       2949  2949
# Ford High School     Government            2739         2739       2739  2739
# Griffin High School  Independent           1468         1468       1468  1468
#
# ...

# %%
school_df = pd.DataFrame(
    grouped_df[["size"]].value_counts())
school_df.head()
# Out:
#                                           0
# school_name          type        size
# Bailey High School   Government  4976  4976
# Cabrera High School  Independent 1858  1858
# Figueroa High School Government  2949  2949
# Ford High School     Government  2739  2739
# Griffin High School  Independent 1468  1468

# %%
# Converting a GroupBy object into a DataFrame
school_df = pd.DataFrame(
    grouped_df[["budget"]].sum())
school_df.head()
# Out:
#                                        budget
# school_name          type
# Bailey High School   Government   15549641728
# Cabrera High School  Independent   2009159448
# Figueroa High School Government    5557128039
# Ford High School     Government    4831365924
# Griffin High School  Independent   1346890000

# %%
school_df = pd.DataFrame(
    grouped_df[["budget"]].sum())
school_df.head()
# Out:
#                                        budget
# school_name          type
# Bailey High School   Government   15549641728
# Cabrera High School  Independent   2009159448
# Figueroa High School Government    5557128039
# Ford High School     Government    4831365924
# Griffin High School  Independent   1346890000

# %%
# Add a new column that calculates the individual budget
school_df["Per Student Budget"] = \
        school_df["budget"] / \
        school_df["Total Students"] 
school_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\mccab\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\mccab\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\mccab\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Students'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
school_names = school_data_complete.rename(
    columns={"size": "Total Students"})
school_names
# Out:
#        Student ID     student_name gender  year         school_name  \
# 0               0     Paul Bradley      M     9   Huang High School
# 1               1     Victor Smith      M    12   Huang High School
# 2               2  Kevin Rodriguez      M    12   Huang High School
# 3               3    Richard Scott      M    12   Huang High School
# 4               4       Bonnie Ray      F     9   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F    12  Thomas High School
# 39166       39166        Dawn Bell      F    10  Thomas High School
# 39167       39167   Rebecca Tanner      F     9  Thomas High School
# 39168       39168     Desiree Kidd      F    10  Thomas High School
# 39169       39169  Carolyn Jackson      F    11  Thomas High School
#
#        reading_score  maths_score  School ID         type  Total Students  \
# 0                 96           94          0   Government            2917
# ...

# %%
#school_names_group = school_df.groupby("school_name", "type")
#school_budget_per_student = pd.DataFrame(school_data_complete[["Total Students",
                                                      #          "maths_score",
                                                              #  "reading_score"]].sum())
#school_budget_per_student.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\mccab\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     549         try:
# --> 550             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551         except KeyError:
#
# KeyError: 'type'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14596\3681659987.py in <module>
# ----> 1 school_names_group = school_df.groupby("school_name", "type")
#       2 school_budget_per_student = pd.DataFrame(school_data_complete[["Total Students",
#       3                                                                 "maths_score",
#       4                                                                 "reading_score"]].sum())
# ...

# %%
merged_df = school_df(
    on=["school_name", "type"]
)

# %%
merged_df["Average Maths Score"] = 
merged_df["Average Reading Score"] = 
merged_df["% Passing Math"] = 
merged_df["% Passing reading"] = 
merged_df["% Overall Passing"]
# Out:
#   File "C:\Users\mccab\AppData\Local\Temp\ipykernel_14596\561927081.py", line 3
#     school_df.head()
#     ^
# SyntaxError: invalid syntax

# %%
data_to_compare = pd.DataFrame([["size",
                                "budget",
                                "Per Student Budget",
                                "Average Maths Score",
                                "Average Reading Score",
                                "% Passing Math",
                                "% Passing Reading",
                                "% Overall Passing"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14596\2344360155.py in <module>
# ----> 1 data_to_compare = pd.DataFrame(merged_df[["size",
#       2                                           "budget",
#       3                                           "Per Student Budget",
#       4                                           "Average Maths Score",
#       5                                           "Average Reading Score",
#
# NameError: name 'merged_df' is not defined

# %%
# Converting a GroupBy object into a DataFrame
school_df = pd.DataFrame(
    grouped_df[["size", "budget"]].value_counts())
school_df.head()
# Out:
#                                                   0
# school_name          type        size budget
# Bailey High School   Government  4976 3124928  4976
# Cabrera High School  Independent 1858 1081356  1858
# Figueroa High School Government  2949 1884411  2949
# Ford High School     Government  2739 1763916  2739
# Griffin High School  Independent 1468 917500   1468

# %%
school_df["Average Maths Score"] = averageMathScore,
school_df.head()
# Out:
#                                                   0  Average Maths Score
# school_name          type        size budget
# Bailey High School   Government  4976 3124928  4976            70.338192
# Cabrera High School  Independent 1858 1081356  1858            70.338192
# Figueroa High School Government  2949 1884411  2949            70.338192
# Ford High School     Government  2739 1763916  2739            70.338192
# Griffin High School  Independent 1468 917500   1468            70.338192

# %%
school_df["Average Reading Score"] = averageReadingScore
school_df.head()
# Out:
#                                                   0  Average Maths Score  \
# school_name          type        size budget
# Bailey High School   Government  4976 3124928  4976            70.338192
# Cabrera High School  Independent 1858 1081356  1858            70.338192
# Figueroa High School Government  2949 1884411  2949            70.338192
# Ford High School     Government  2739 1763916  2739            70.338192
# Griffin High School  Independent 1468 917500   1468            70.338192
#
#                                                Average Reading Score
# school_name          type        size budget
# Bailey High School   Government  4976 3124928              69.980138
# Cabrera High School  Independent 1858 1081356              69.980138
# Figueroa High School Government  2949 1884411              69.980138
# Ford High School     Government  2739 1763916              69.980138
# Griffin High School  Independent 1468 917500               69.980138

# %%
school_df =
# Out:
#        Student ID     student_name gender  year         school_name  \
# 0               0     Paul Bradley      M     9   Huang High School
# 1               1     Victor Smith      M    12   Huang High School
# 2               2  Kevin Rodriguez      M    12   Huang High School
# 3               3    Richard Scott      M    12   Huang High School
# 4               4       Bonnie Ray      F     9   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F    12  Thomas High School
# 39166       39166        Dawn Bell      F    10  Thomas High School
# 39167       39167   Rebecca Tanner      F     9  Thomas High School
# 39168       39168     Desiree Kidd      F    10  Thomas High School
# 39169       39169  Carolyn Jackson      F    11  Thomas High School
#
#        reading_score  maths_score  School ID         type  Total Students  \
# 0                 96           94          0   Government            2917
# ...

# %%
# Save toilets and tables sums as series
averageMathScore = school_data_complete["maths_score"].mean()
averageReadingScore = school_data_complete["reading_score"].mean()

# %%
# top performing schools (Q3)
# Sort the data by Health Expenditure (% GDP), Highest to Lowest
school_sorted_highest = school_df.sort_values(["maths_score"],
                                           ascending=False)
school_sorted_highest = school_sorted_highest.reset_index(drop=True)
school_sorted_highest.head()

# %%
# Bottom performing schools (Q4)
school_sorted_lowest = school_df.sort_values(["maths_score"],
                                           ascending=True)
school_sorted_lowest = school_sorted_lowest.reset_index(drop=True)
school_sorted_lowest.head()

# %%
# Maths Score by year (Q5)

# %%
# Maths Score by yr (Q6)

# %%
# reading score by yr (Q7)

# %%
# Scores by school spending (Q8)

# %%
# Scores by school side (Q9)

# %%
# Scores by School type (Q10)

# %%
#formatting
school_data_complete[""]
